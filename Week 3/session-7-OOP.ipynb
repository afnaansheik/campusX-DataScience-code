# %%
L = [1,2,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 L = [1,2,4]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = 'hello'
# ----> 2 s.append('x')
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# ## OOP's give you power to create your onw data type

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# so there is a file list.py in that code is written, what function can we use on list

# %%
# class is blue print 
# set of rules
# every data type is class and variable is objects

# %%
# car is class 
# defender is object

# %%
# syntax to create an object
# objectname = classname()

# %%
# we can also create list as this
# objectname = classname()
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %% [markdown]
# <center> Banking code with OOP<center>

# %%
# Pascal Case
HelloWorld

# %%
class Atm:

    # constructor() special finction -> superpower ->when object is created it call by default call constructor func
    def __init__(self):
        self.pin = ''
        self.balance = 0
        # print('abey mai print hogay')
        self.menu()

    def menu(self):
        user_input = input("""
            Hi how can i help you?
            1. press 1 to create pin
            2. press 2 to change pin
            3. press 3 to check balance 
            4. press 4 to withraw
            5. Anything else to exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            # change pin
            self.change_pin()
        elif user_input == '3':
            self.check_balance()
        elif user_input == '4':
            self.withraw()
            
        else:
            exit()

    def create_pin(self):
        user_pin = input('enter the pin')
        self.pin = user_pin

        user_balance = int(input('enter balance'))
        self.balance = user_balance

        print('Pin created Suceessfully')
        self.menu()

    def change_pin(self):

        old_pin = (input('enter old pin'))

        if old_pin == self.pin:
            change_pin = int(input('enter new pin'))
            self.pin= change_pin
            self.menu()
            print('pin changed successfuly')
        else:
            print('you entered wrong pin')
            self.menu()

    def check_balance(self):
        user_pin = input('enter current pin')
        if user_pin == self.pin:
            print('your balance is',self.balance)
        else:
            print('chal nikal ya  se')

    def withraw(self):
        user_pin = input('enter current pin')
        if user_pin == self.pin:
            amount = int(input('enter amount you want to withraw'))
            self.balance = self.balance - amount

            print(amount,'has been deducted')
            print('remaining balance:',self.balance)

        else:
            print('Enter the correct pin')
            self.menu()

# %%
custormer1 = Atm()
# Out:
# Pin created Suceessfully
# Enter the correct pin
# 390 has been deducted
# remaining balance: 610

# %% [markdown]
# ### Fuction Vs Method

# %%
class Car:

    def start_car(self): #method
        print('car started..')

    def stop_car(self): #method
        print('car stop..')


def welcome(): #function
    print('Hello Sir')

""" 
inside class function is called method
outside class is function is thr then called function.
"""
# Out:
# ' \ninside class function is called method\noutside class is function is thr then called function.\n'

# %%
car1 = Car()
car1.start_car()
# Out:
# car started..

# %%
# Q what is method & function in this snipted
L = [1,2,3]

len(L)

L.append(5)

# %% [markdown]
# ## class Diagram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Magic Method

# %% [markdown]
# - magic -> speacial -> superpower
#
#         __init__ is a magic method (constructor)
#
#         __name__ is also magic method

# %% [markdown]
# - with this magic method we will learn to create our own data type's

# %% [markdown]
# <!-- more 5 magic method wil learn -->

# %%
# what is constructor?
""" 
constructor is a method but it's a specail method & it has got superpower
superpower mean it automatically trigger without calling it.
"""

# %%
# why constructor is used?
""" 
Other methods start only when the user calls them, e.g., check_balance, withdraw or book uber. So we give the user control to run that code.
But the constructor runs automatically once the object is created.
We don't give the user the power to run that code — it runs automatically when the program or application starts.
Constructor is used to write configuration code (like connecting to a database) or connecting the application to the internet.
"""

# %%
# say god is programmer , the Earth is class & human's are object then what will be in constructor code?
""" 
death control code in constructor
"""

# %% [markdown]
#  ## Golden Rule Of Object Oriented Programming

# %% [markdown]
# - Object it can actually access everything that is present inside a class.
# - and again i am saying only object

# %%
# so one method is can talk to other method
# eg. withraw method is trying to talk to check_balance() method 
# no it can't as golden role say only object.

# %% [markdown]
# ## self

# %%
# self is nothing but the current object.
# whc can access everthing from class

# %%
class Car:

    def __init__(self):
        print(self)

c1 = Car()
print(c1)

# can be seen adrress of self & c1 object is same.

# %%
# as oop say no other function or method can access other method so we pass self para to use all method of class

# %% [markdown]
# ## creating our own data type

# %% [markdown]
# - in python there are float,complex data type but no fraction data type
# - so we wil implement that

# %%
1/3 * 1/3
# Out:
# 0.1111111111111111

# %%
# ans is in decimal i want in fracrion 1/9

# %%
class Fraction:

    # paramitarized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y

# %%
obj1 = Fraction(2,4)

# %%
print(obj1) #it's telling fraction object at this address.

# %%
# we want to show as 2/4 
# so we will use magic method that __str__ this tell py interpretor what to display

class Fraction:

    # paramitarized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y

    def __str__(self):
        return '{}/{}'.format(self.num,self.den)

# %%
obj1 = Fraction(2,4)

# %%
print(obj1)
# Out:
# 2/4

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
fr1 + fr2
# Out:
# '10/8'

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

# __add__ ,__sub__,__mul__,__truediv__ your magic method
  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)

    # create own magic method
  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
# create own magic method
fr1.convert_to_decimal()
# 3/4
# Out:
# 0.75
